# %%
#CHECK GPU
# !nvidia-smi
# Out:
# Mon Oct  2 23:25:24 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.113.01             Driver Version: 535.113.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    Off | 00000000:01:00.0 Off |                  N/A |
# | N/A   57C    P0              22W /  70W |      9MiB /  6144MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2687      G   /usr/lib/xorg/Xorg                            4MiB |
# +---------------------------------------------------------------------------------------+

# %%
# !python -m pip install --upgrade pip
# !pip install ultralytics==8.0.20
# !pip install roboflow --quiet
# !pip install pycuda
# !pip install opencv-python
# !pip install tensorflow
# !pip install opencv-python
# !pip install pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /usr/lib/python3/dist-packages (22.0.2)
# Collecting pip
#   Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
# Successfully installed pip-23.2.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ultralytics==8.0.20
#   Downloading ultralytics-8.0.20-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 5.1 MB/s eta 0:00:00a 0:00:01
# Collecting matplotlib>=3.2.2 (from ultralytics==8.0.20)
#   Obtaining dependency information for matplotlib>=3.2.2 from https://files.pythonhosted.org/packages/b5/24/aaccf324ce862bb82277e8814d2aebbb2a2c160d04e95aa2b8c9dc3137a9/matplotlib-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading matplotlib-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting numpy>=1.18.5 (from ultralytics==8.0.20)
#   Obtaining dependency information for numpy>=1.18.5 from https://files.pythonhosted.org/packages/9b/5a/f265a1ba3641d16b5480a217a6aed08cceef09cd173b568cd5351053472a/numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 4.4 MB/s eta 0:00:00
# Collecting opencv-python>=4.6.0 (from ultralytics==8.0.20)
#   Obtaining dependency information for opencv-python>=4.6.0 from https://files.pythonhosted.org/packages/b7/8a/b2f7e1a434d56bf1d7570fc5941ace0847404e1032d7f1f0b8fed896568d/opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/lib/python3/dist-packages (from ultralytics==8.0.20) (9.0.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/lib/python3/dist-packages (from ultralytics==8.0.20) (5.4.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/lib/python3/dist-packages (from ultralytics==8.0.20) (2.25.1)
# Collecting scipy>=1.4.1 (from ultralytics==8.0.20)
#   Obtaining dependency information for scipy>=1.4.1 from https://files.pythonhosted.org/packages/18/44/7e8d208eb59a8224fcc474415104f13be9b378be8da63f76dfde12ec2b44/scipy-1.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scipy-1.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.0 MB/s eta 0:00:00
# Collecting torch>=1.7.0 (from ultralytics==8.0.20)
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 3.4 MB/s eta 0:00:0000:0100:03
# Collecting torchvision>=0.8.1 (from ultralytics==8.0.20)
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 5.3 MB/s eta 0:00:0000:0100:01
# Collecting tqdm>=4.64.0 (from ultralytics==8.0.20)
#   Obtaining dependency information for tqdm>=4.64.0 from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 9.0 MB/s eta 0:00:00
# Collecting tensorboard>=2.4.1 (from ultralytics==8.0.20)
#   Obtaining dependency information for tensorboard>=2.4.1 from https://files.pythonhosted.org/packages/73/a2/66ed644f6ed1562e0285fcd959af17670ea313c8f331c46f79ee77187eb9/tensorboard-2.14.1-py3-none-any.whl.metadata
#   Downloading tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting pandas>=1.1.4 (from ultralytics==8.0.20)
#   Obtaining dependency information for pandas>=1.1.4 from https://files.pythonhosted.org/packages/2f/0e/3b74e8f7c908082793adafb02753477f653ccd7e189f3ba070757d2d0e65/pandas-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pandas-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting seaborn>=0.11.0 (from ultralytics==8.0.20)
#   Obtaining dependency information for seaborn>=0.11.0 from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: ipython in /home/paragmraw/.local/lib/python3.10/site-packages (from ultralytics==8.0.20) (8.16.1)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from ultralytics==8.0.20) (5.9.0)
# Collecting thop>=0.1.1 (from ultralytics==8.0.20)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting sentry-sdk (from ultralytics==8.0.20)
#   Obtaining dependency information for sentry-sdk from https://files.pythonhosted.org/packages/62/3a/765a7699a26884dcbf8b071dbe2a2486cc1cafcfb5f5d2e64ffe745dd0c6/sentry_sdk-1.31.0-py2.py3-none-any.whl.metadata
#   Downloading sentry_sdk-1.31.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.2.2->ultralytics==8.0.20)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/f1/6b/e4b0f8708f22dd7c321f87eadbb98708975e115ac6582eb46d1f32197ce6/contourpy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading contourpy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.2.2->ultralytics==8.0.20)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/2b/b3/70c33027c4918c10ccf176014b38f8b91cb18ac018a78854543a4fc72609/cycler-0.12.0-py3-none-any.whl.metadata
#   Downloading cycler-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.2.2->ultralytics==8.0.20)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/30/fd/821dc3ba5d179bd9b20bf9a9c2251132a8f1067818d19fcafc987727ddaa/fonttools-4.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading fonttools-4.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 5.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib>=3.2.2->ultralytics==8.0.20)
#   Obtaining dependency information for kiwisolver>=1.0.1 from https://files.pythonhosted.org/packages/6f/40/4ab1fdb57fced80ce5903f04ae1aed7c1d5939dda4fd0c0aa526c12fe28a/kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.20) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.20) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/paragmraw/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.20) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.1.4->ultralytics==8.0.20) (2022.1)
# Collecting tzdata>=2022.1 (from pandas>=1.1.4->ultralytics==8.0.20)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 7.0 MB/s eta 0:00:00a 0:00:01
# Collecting absl-py>=0.4 (from tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for absl-py>=0.4 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for grpcio>=1.48.2 from https://files.pythonhosted.org/packages/20/7f/e76618521aa9d33c6c1c9c3473f866da521678aa6ea2f4df3a896757748c/grpcio-1.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading grpcio-1.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/d7/88/1826b0c047c48763b36ed854a984127b430a16b70003155d7b19975f1d59/google_auth-2.23.2-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.23.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard>=2.4.1->ultralytics==8.0.20)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/1a/b5/228c1cdcfe138f1a8e01ab1b54284c8b83735476cb22b6ba251656ed13ad/Markdown-3.4.4-py3-none-any.whl.metadata
#   Downloading Markdown-3.4.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting protobuf>=3.19.6 (from tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for protobuf>=3.19.6 from https://files.pythonhosted.org/packages/bb/c3/6a06208ecf0934ecaf509b51c52a6cf688586f54ae81ac65c56124571494/protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.20) (59.6.0)
# Requirement already satisfied: six>1.9 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.20) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/02/52/fb9e51fba47951aabd7a6b25e41d73eae94208ccf62d886168096941a781/tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/b6/a5/54b01f663d60d5334f6c9c87c26274e94617a4fd463d812463626423b10d/werkzeug-3.0.0-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting filelock (from torch>=1.7.0->ultralytics==8.0.20)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/5e/5d/97afbafd9d584ff1b45fcb354a479a3609bd97f912f8f1f6c563cb1fae21/filelock-3.12.4-py3-none-any.whl.metadata
#   Downloading filelock-3.12.4-py3-none-any.whl.metadata (2.8 kB)
# Collecting typing-extensions (from torch>=1.7.0->ultralytics==8.0.20)
#   Obtaining dependency information for typing-extensions from https://files.pythonhosted.org/packages/24/21/7d397a4b7934ff4028987914ac1044d3b7d52712f30e2ac7a2ae5bc86dd0/typing_extensions-4.8.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 6.6 MB/s eta 0:00:0000:0100:01
# Collecting networkx (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.7.0->ultralytics==8.0.20) (3.0.3)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 6.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 7.0 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 5.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.6 MB/s eta 0:00:0000:0100:03
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.4 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 4.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 5.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 5.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 4.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu11==2.14.3 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 5.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Collecting triton==2.0.0 (from torch>=1.7.0->ultralytics==8.0.20)
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 5.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->ultralytics==8.0.20) (0.37.1)
# Collecting cmake (from triton==2.0.0->torch>=1.7.0->ultralytics==8.0.20)
#   Obtaining dependency information for cmake from https://files.pythonhosted.org/packages/72/89/b1cf3cd5fb9f4ae796dd4a743412553f884dad2acbf6b9828d3a0c2b5524/cmake-3.27.6-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Downloading cmake-3.27.6-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.7 kB)
# Collecting lit (from triton==2.0.0->torch>=1.7.0->ultralytics==8.0.20)
#   Downloading lit-17.0.1.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 5.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: backcall in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (0.2.0)
# Requirement already satisfied: decorator in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (0.1.6)
# Requirement already satisfied: pickleshare in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (2.16.1)
# Requirement already satisfied: stack-data in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (5.10.1)
# Requirement already satisfied: exceptiongroup in /home/paragmraw/.local/lib/python3.10/site-packages (from ipython->ultralytics==8.0.20) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->ultralytics==8.0.20) (4.8.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from sentry-sdk->ultralytics==8.0.20) (2020.6.20)
# Collecting urllib3>=1.26.11 (from sentry-sdk->ultralytics==8.0.20)
#   Obtaining dependency information for urllib3>=1.26.11 from https://files.pythonhosted.org/packages/26/40/9957270221b6d3e9a3b92fdfba80dd5c9661ff45a664b47edd5d00f707f5/urllib3-2.0.6-py3-none-any.whl.metadata
#   Downloading urllib3-2.0.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.20)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 6.0 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.20)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->ultralytics==8.0.20)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/paragmraw/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython->ultralytics==8.0.20) (0.8.3)
# Requirement already satisfied: wcwidth in /home/paragmraw/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->ultralytics==8.0.20) (0.2.8)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard>=2.4.1->ultralytics==8.0.20)
#   Obtaining dependency information for MarkupSafe>=2.1.1 from https://files.pythonhosted.org/packages/12/b3/d9ed2c0971e1435b8a62354b18d3060b66c8cb1d368399ec0b9baa7c0ee5/MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: executing>=1.2.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.20) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.20) (2.4.0)
# Requirement already satisfied: pure-eval in /home/paragmraw/.local/lib/python3.10/site-packages (from stack-data->ipython->ultralytics==8.0.20) (0.2.2)
# Collecting mpmath>=0.19 (from sympy->torch>=1.7.0->ultralytics==8.0.20)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 7.2 MB/s eta 0:00:0000:0100:01
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.20)
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->ultralytics==8.0.20) (3.2.0)
# Downloading matplotlib-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 6.2 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 5.4 MB/s eta 0:00:0000:0100:01
# Downloading opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 5.7 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 5.9 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 5.7 MB/s eta 0:00:0000:0100:01
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 6.2 MB/s eta 0:00:0000:0100:01
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 9.6 MB/s eta 0:00:00
# Downloading sentry_sdk-1.31.0-py2.py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 7.6 MB/s eta 0:00:00
# Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 7.3 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.7/301.7 kB 7.6 MB/s eta 0:00:0000:01
# Downloading cycler-0.12.0-py3-none-any.whl (8.2 kB)
# Downloading fonttools-4.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 6.1 MB/s eta 0:00:0000:0100:01
# Downloading google_auth-2.23.2-py2.py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 4.5 MB/s eta 0:00:00a 0:00:01
# Downloading grpcio-1.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 6.8 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.2 MB/s eta 0:00:00a 0:00:01
# Downloading Markdown-3.4.4-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 3.2 MB/s eta 0:00:00
# Downloading protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 6.3 MB/s eta 0:00:0000:0100:01
# Downloading urllib3-2.0.6-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 4.2 MB/s eta 0:00:00
# Downloading werkzeug-3.0.0-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.6/226.6 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Downloading filelock-3.12.4-py3-none-any.whl (11 kB)
# Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Downloading MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading cmake-3.27.6-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (26.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 5.9 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: lit
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-17.0.1-py3-none-any.whl size=93254 sha256=ecd71b5b8c233a14cf73ef73e439cfc69cc66330cae39719303a7486da65d03b
#   Stored in directory: /home/paragmraw/.cache/pip/wheels/cf/3a/a0/f65551951357f983270eb3b210b98c6be543f3ed5cf89deba4
# Successfully built lit
# Installing collected packages: mpmath, lit, cmake, urllib3, tzdata, typing-extensions, tqdm, tensorboard-data-server, sympy, requests-oauthlib, pyasn1, protobuf, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, numpy, networkx, MarkupSafe, markdown, kiwisolver, grpcio, fonttools, filelock, cycler, cachetools, absl-py, werkzeug, sentry-sdk, scipy, rsa, pyasn1-modules, pandas, opencv-python, nvidia-cusolver-cu11, nvidia-cudnn-cu11, contourpy, matplotlib, google-auth, seaborn, google-auth-oauthlib, tensorboard, triton, torch, torchvision, thop, ultralytics
# Successfully installed MarkupSafe-2.1.3 absl-py-2.0.0 cachetools-5.3.1 cmake-3.27.6 contourpy-1.1.1 cycler-0.12.0 filelock-3.12.4 fonttools-4.43.0 google-auth-2.23.2 google-auth-oauthlib-1.0.0 grpcio-1.59.0 kiwisolver-1.4.5 lit-17.0.1 markdown-3.4.4 matplotlib-3.8.0 mpmath-1.3.0 networkx-3.1 numpy-1.26.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 opencv-python-4.8.1.78 pandas-2.1.1 protobuf-4.24.3 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 scipy-1.11.3 seaborn-0.13.0 sentry-sdk-1.31.0 sympy-1.12 tensorboard-2.14.1 tensorboard-data-server-0.7.1 thop-0.1.1.post2209072238 torch-2.0.1 torchvision-0.15.2 tqdm-4.66.1 triton-2.0.0 typing-extensions-4.8.0 tzdata-2023.3 ultralytics-8.0.20 urllib3-2.0.6 werkzeug-3.0.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pycuda
#   Downloading pycuda-2022.2.2.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.0 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytools>=2011.2 (from pycuda)
#   Obtaining dependency information for pytools>=2011.2 from https://files.pythonhosted.org/packages/3d/4b/4cbe808b38ee25d3c3f1b1b99bde39cef43c30df64416b62e28079404d1b/pytools-2023.1.1-py2.py3-none-any.whl.metadata
#   Downloading pytools-2023.1.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting appdirs>=1.4.0 (from pycuda)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting mako (from pycuda)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.2.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from pytools>=2011.2->pycuda) (3.11.0)
# Requirement already satisfied: typing-extensions>=4.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from pytools>=2011.2->pycuda) (4.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/paragmraw/.local/lib/python3.10/site-packages (from mako->pycuda) (2.1.3)
# Downloading pytools-2023.1.1-py2.py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 8.8 MB/s eta 0:00:00
# Building wheels for collected packages: pycuda
#   Building wheel for pycuda (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pycuda (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [12327 lines of output]
#       ***************************************************************
#       *** WARNING: nvcc not in path.
#       *** May need to set CUDA_INC_DIR for installation to succeed.
#       ***************************************************************
#       *************************************************************
#       *** I have detected that you have not run configure.py.
#       *************************************************************
#       *** Additionally, no global config files were found.
#       *** I will go ahead with the default configuration.
#       *** In all likelihood, this will not work out.
#       ***
#       *** See README_SETUP.txt for more information.
#       ***
#       *** If the build does fail, just re-run configure.py with the
#       *** correct arguments, and then retry. Good luck!
#       *************************************************************
#       *** HIT Ctrl-C NOW IF THIS IS NOT WHAT YOU WANT
#       *************************************************************
#       Continuing in 10 seconds...
#       Continuing in 9 seconds...
#       Continuing in 8 seconds...
#       Continuing in 7 seconds...
#       Continuing in 6 seconds...
#       Continuing in 5 seconds...
#       Continuing in 4 seconds...
#       Continuing in 3 seconds...
#       Continuing in 2 seconds...
#       Continuing in 1 seconds...
#       /tmp/pip-build-env-xuwyzvs7/overlay/local/lib/python3.10/dist-packages/setuptools/_distutils/dist.py:265: UserWarning: Unknown distribution option: 'test_requires'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-310
#       creating build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/tools.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/curandom.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/autoinit.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/reduction.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/_mymako.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/characterize.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/gpuarray.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/elementwise.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/__init__.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/autoprimaryctx.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/debug.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/_cluda.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/compiler.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/scan.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/cumath.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       copying pycuda/driver.py -> build/lib.linux-x86_64-cpython-310/pycuda
#       creating build/lib.linux-x86_64-cpython-310/pycuda/gl
#       copying pycuda/gl/autoinit.py -> build/lib.linux-x86_64-cpython-310/pycuda/gl
#       copying pycuda/gl/__init__.py -> build/lib.linux-x86_64-cpython-310/pycuda/gl
#       creating build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       copying pycuda/sparse/inner.py -> build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       copying pycuda/sparse/packeted.py -> build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       copying pycuda/sparse/coordinate.py -> build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       copying pycuda/sparse/__init__.py -> build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       copying pycuda/sparse/pkt_build.py -> build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       copying pycuda/sparse/cg.py -> build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       copying pycuda/sparse/operator.py -> build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       creating build/lib.linux-x86_64-cpython-310/pycuda/compyte
#       copying pycuda/compyte/__init__.py -> build/lib.linux-x86_64-cpython-310/pycuda/compyte
#       copying pycuda/compyte/array.py -> build/lib.linux-x86_64-cpython-310/pycuda/compyte
#       copying pycuda/compyte/dtypes.py -> build/lib.linux-x86_64-cpython-310/pycuda/compyte
#       running egg_info
#       writing pycuda.egg-info/PKG-INFO
#       writing dependency_links to pycuda.egg-info/dependency_links.txt
#       writing requirements to pycuda.egg-info/requires.txt
#       writing top-level names to pycuda.egg-info/top_level.txt
#       reading manifest file 'pycuda.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching 'doc/source/*.rst'
#       warning: no files found matching 'doc/source/conf.py'
#       warning: no files found matching 'doc/source/_static/*.css'
#       warning: no files found matching 'doc/source/_templates/*.html'
#       warning: no files found matching '*.cpp' under directory 'bpl-subset/bpl_subset/boost'
#       warning: no files found matching '*.html' under directory 'bpl-subset/bpl_subset/boost'
#       warning: no files found matching '*.inl' under directory 'bpl-subset/bpl_subset/boost'
#       warning: no files found matching '*.txt' under directory 'bpl-subset/bpl_subset/boost'
#       warning: no files found matching '*.h' under directory 'bpl-subset/bpl_subset/libs'
#       warning: no files found matching '*.ipp' under directory 'bpl-subset/bpl_subset/libs'
#       warning: no files found matching '*.pl' under directory 'bpl-subset/bpl_subset/libs'
#       adding license file 'LICENSE'
#       writing manifest file 'pycuda.egg-info/SOURCES.txt'
#       /tmp/pip-build-env-xuwyzvs7/overlay/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:204: _Warning: Package 'pycuda.cuda' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'pycuda.cuda' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'pycuda.cuda' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'pycuda.cuda' to be distributed and are
#               already explicitly excluding 'pycuda.cuda' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       creating build/lib.linux-x86_64-cpython-310/pycuda/cuda
#       copying pycuda/cuda/pycuda-complex-impl.hpp -> build/lib.linux-x86_64-cpython-310/pycuda/cuda
#       copying pycuda/cuda/pycuda-complex.hpp -> build/lib.linux-x86_64-cpython-310/pycuda/cuda
#       copying pycuda/cuda/pycuda-helpers.hpp -> build/lib.linux-x86_64-cpython-310/pycuda/cuda
#       copying pycuda/sparse/pkt_build_cython.pyx -> build/lib.linux-x86_64-cpython-310/pycuda/sparse
#       running build_ext
#       building '_driver' extension
#       creating build/temp.linux-x86_64-cpython-310
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/python
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/python/src
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/python/src/converter
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/python/src/object
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/smart_ptr
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/smart_ptr/src
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/system
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/system/src
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/thread
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/thread/src
#       creating build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/thread/src/pthread
#       creating build/temp.linux-x86_64-cpython-310/src
#       creating build/temp.linux-x86_64-cpython-310/src/cpp
#       creating build/temp.linux-x86_64-cpython-310/src/wrapper
#       x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -fwrapv -Wall -O3 -DNDEBUG -fPIC -DBOOST_ALL_NO_LIB=1 -DBOOST_THREAD_BUILD_DLL=1 -DBOOST_MULTI_INDEX_DISABLE_SERIALIZATION=1 -DBOOST_PYTHON_SOURCE=1 -Dboost=pycudaboost -DBOOST_THREAD_DONT_USE_CHRONO=1 -DPYGPU_PACKAGE=pycuda -DPYGPU_PYCUDA=1 -DHAVE_CURAND=1 -Isrc/cpp -Ibpl-subset/bpl_subset -I/tmp/pip-build-env-xuwyzvs7/overlay/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c bpl-subset/bpl_subset/libs/python/src/converter/arg_to_python_base.cpp -o build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/python/src/converter/arg_to_python_base.o
#       In file included from bpl-subset/bpl_subset/boost/python/handle.hpp:10,
#                        from bpl-subset/bpl_subset/boost/python/converter/arg_to_python_base.hpp:7,
#                        from bpl-subset/bpl_subset/libs/python/src/converter/arg_to_python_base.cpp:6:
#       bpl-subset/bpl_subset/boost/python/cast.hpp: In function ‘void pycudaboost::python::detail::assert_castable(pycudaboost::type<Target>*)’:
#       bpl-subset/bpl_subset/boost/python/cast.hpp:73:20: warning: typedef ‘must_be_a_complete_type’ locally defined but not used [-Wunused-local-typedefs]
#          73 |       typedef char must_be_a_complete_type[sizeof(T)];
#             |                    ^~~~~~~~~~~~~~~~~~~~~~~
#       In file included from bpl-subset/bpl_subset/boost/bind/mem_fn.hpp:25,
#                        from bpl-subset/bpl_subset/boost/mem_fn.hpp:22,
#                        from bpl-subset/bpl_subset/boost/function/detail/prologue.hpp:18,
#                        from bpl-subset/bpl_subset/boost/function/function_template.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/detail/maybe_include.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/function0.hpp:11,
#                        from bpl-subset/bpl_subset/boost/python/errors.hpp:13,
#                        from bpl-subset/bpl_subset/boost/python/handle.hpp:11,
#                        from bpl-subset/bpl_subset/boost/python/converter/arg_to_python_base.hpp:7,
#                        from bpl-subset/bpl_subset/libs/python/src/converter/arg_to_python_base.cpp:6:
#       bpl-subset/bpl_subset/boost/get_pointer.hpp: At global scope:
#       bpl-subset/bpl_subset/boost/get_pointer.hpp:25:40: warning: ‘template<class> class std::auto_ptr’ is deprecated: use 'std::unique_ptr' instead [-Wdeprecated-declarations]
#          25 | template<class T> T * get_pointer(std::auto_ptr<T> const& p)
#             |                                        ^~~~~~~~
#       In file included from /usr/include/c++/11/memory:76,
#                        from bpl-subset/bpl_subset/boost/function/function_base.hpp:16,
#                        from bpl-subset/bpl_subset/boost/function/detail/prologue.hpp:17,
#                        from bpl-subset/bpl_subset/boost/function/function_template.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/detail/maybe_include.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/function0.hpp:11,
#                        from bpl-subset/bpl_subset/boost/python/errors.hpp:13,
#                        from bpl-subset/bpl_subset/boost/python/handle.hpp:11,
#                        from bpl-subset/bpl_subset/boost/python/converter/arg_to_python_base.hpp:7,
#                        from bpl-subset/bpl_subset/libs/python/src/converter/arg_to_python_base.cpp:6:
#       /usr/include/c++/11/bits/unique_ptr.h:57:28: note: declared here
#          57 |   template<typename> class auto_ptr;
#             |                            ^~~~~~~~
#       x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -fwrapv -Wall -O3 -DNDEBUG -fPIC -DBOOST_ALL_NO_LIB=1 -DBOOST_THREAD_BUILD_DLL=1 -DBOOST_MULTI_INDEX_DISABLE_SERIALIZATION=1 -DBOOST_PYTHON_SOURCE=1 -Dboost=pycudaboost -DBOOST_THREAD_DONT_USE_CHRONO=1 -DPYGPU_PACKAGE=pycuda -DPYGPU_PYCUDA=1 -DHAVE_CURAND=1 -Isrc/cpp -Ibpl-subset/bpl_subset -I/tmp/pip-build-env-xuwyzvs7/overlay/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c bpl-subset/bpl_subset/libs/python/src/converter/builtin_converters.cpp -o build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/python/src/converter/builtin_converters.o
#       In file included from bpl-subset/bpl_subset/boost/python/handle.hpp:10,
#                        from bpl-subset/bpl_subset/libs/python/src/converter/builtin_converters.cpp:6:
#       bpl-subset/bpl_subset/boost/python/cast.hpp: In function ‘void pycudaboost::python::detail::assert_castable(pycudaboost::type<Target>*)’:
#       bpl-subset/bpl_subset/boost/python/cast.hpp:73:20: warning: typedef ‘must_be_a_complete_type’ locally defined but not used [-Wunused-local-typedefs]
#          73 |       typedef char must_be_a_complete_type[sizeof(T)];
#             |                    ^~~~~~~~~~~~~~~~~~~~~~~
#       In file included from bpl-subset/bpl_subset/boost/bind/mem_fn.hpp:25,
#                        from bpl-subset/bpl_subset/boost/mem_fn.hpp:22,
#                        from bpl-subset/bpl_subset/boost/function/detail/prologue.hpp:18,
#                        from bpl-subset/bpl_subset/boost/function/function_template.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/detail/maybe_include.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/function0.hpp:11,
#                        from bpl-subset/bpl_subset/boost/python/errors.hpp:13,
#                        from bpl-subset/bpl_subset/boost/python/handle.hpp:11,
#                        from bpl-subset/bpl_subset/libs/python/src/converter/builtin_converters.cpp:6:
#       bpl-subset/bpl_subset/boost/get_pointer.hpp: At global scope:
#       bpl-subset/bpl_subset/boost/get_pointer.hpp:25:40: warning: ‘template<class> class std::auto_ptr’ is deprecated: use 'std::unique_ptr' instead [-Wdeprecated-declarations]
#          25 | template<class T> T * get_pointer(std::auto_ptr<T> const& p)
#             |                                        ^~~~~~~~
#       In file included from /usr/include/c++/11/memory:76,
#                        from bpl-subset/bpl_subset/boost/function/function_base.hpp:16,
#                        from bpl-subset/bpl_subset/boost/function/detail/prologue.hpp:17,
#                        from bpl-subset/bpl_subset/boost/function/function_template.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/detail/maybe_include.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/function0.hpp:11,
#                        from bpl-subset/bpl_subset/boost/python/errors.hpp:13,
#                        from bpl-subset/bpl_subset/boost/python/handle.hpp:11,
#                        from bpl-subset/bpl_subset/libs/python/src/converter/builtin_converters.cpp:6:
#       /usr/include/c++/11/bits/unique_ptr.h:57:28: note: declared here
#          57 |   template<typename> class auto_ptr;
#             |                            ^~~~~~~~
#       x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -fwrapv -Wall -O3 -DNDEBUG -fPIC -DBOOST_ALL_NO_LIB=1 -DBOOST_THREAD_BUILD_DLL=1 -DBOOST_MULTI_INDEX_DISABLE_SERIALIZATION=1 -DBOOST_PYTHON_SOURCE=1 -Dboost=pycudaboost -DBOOST_THREAD_DONT_USE_CHRONO=1 -DPYGPU_PACKAGE=pycuda -DPYGPU_PYCUDA=1 -DHAVE_CURAND=1 -Isrc/cpp -Ibpl-subset/bpl_subset -I/tmp/pip-build-env-xuwyzvs7/overlay/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c bpl-subset/bpl_subset/libs/python/src/converter/from_python.cpp -o build/temp.linux-x86_64-cpython-310/bpl-subset/bpl_subset/libs/python/src/converter/from_python.o
#       In file included from bpl-subset/bpl_subset/boost/python/handle.hpp:10,
#                        from bpl-subset/bpl_subset/libs/python/src/converter/from_python.cpp:12:
#       bpl-subset/bpl_subset/boost/python/cast.hpp: In function ‘void pycudaboost::python::detail::assert_castable(pycudaboost::type<Target>*)’:
#       bpl-subset/bpl_subset/boost/python/cast.hpp:73:20: warning: typedef ‘must_be_a_complete_type’ locally defined but not used [-Wunused-local-typedefs]
#          73 |       typedef char must_be_a_complete_type[sizeof(T)];
#             |                    ^~~~~~~~~~~~~~~~~~~~~~~
#       In file included from bpl-subset/bpl_subset/boost/bind/mem_fn.hpp:25,
#                        from bpl-subset/bpl_subset/boost/mem_fn.hpp:22,
#                        from bpl-subset/bpl_subset/boost/function/detail/prologue.hpp:18,
#                        from bpl-subset/bpl_subset/boost/function/function_template.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/detail/maybe_include.hpp:13,
#                        from bpl-subset/bpl_subset/boost/function/function0.hpp:11,
#                        from bpl-subset/bpl_subset/boost/python/errors.hpp:13,
#                        from bpl-subset/bpl_subset/boost/python/handle.hpp:11,
#                        from bpl-subset/bpl_subset/libs/python/src/converter/from_python.cpp:12:
#       bpl-subset/bpl_subset/boost/get_pointer.hpp: At global scope:
#       bpl-subset/bpl_subset/boost/get_pointer.hpp:25:40: warning: ‘template<class> class std::auto_ptr’ is deprecated: use 'std::unique_ptr' instead [-Wdeprecated-declarations]
#          25 | template<class T> T * get_pointer(std::auto_ptr<T> const& p)
#             |                                        ^~~~~~~~
#       In file included from /usr/include/c++/11/memory:76,
# ...
#       bpl-subset/bpl_subset/boost/get_pointer.hpp: At global scope:
#       bpl-subset/bpl_subset/boost/get_pointer.hpp:25:40: warning: ‘template<class> class std::auto_ptr’ is deprecated: use 'std::unique_ptr' instead [-Wdeprecated-declarations]
#          25 | template<class T> T * get_pointer(std::auto_ptr<T> const& p)
#             |                                        ^~~~~~~~
#       In file included from /usr/include/c++/11/memory:76,
#                        from bpl-subset/bpl_subset/boost/move/move.hpp:38,
#                        from bpl-subset/bpl_subset/boost/thread/detail/move.hpp:20,
#                        from bpl-subset/bpl_subset/boost/thread/locks.hpp:11,
#                        from bpl-subset/bpl_subset/boost/thread/pthread/thread_data.hpp:11,
#                        from bpl-subset/bpl_subset/boost/thread/thread.hpp:17,
#                        from bpl-subset/bpl_subset/libs/thread/src/pthread/thread.cpp:11:
#       /usr/include/c++/11/bits/unique_ptr.h:57:28: note: declared here
#          57 |   template<typename> class auto_ptr;
#             |                            ^~~~~~~~
#       In file included from bpl-subset/bpl_subset/boost/bind/bind.hpp:29,
#                        from bpl-subset/bpl_subset/boost/bind.hpp:22,
#                        from bpl-subset/bpl_subset/boost/thread/detail/thread.hpp:23,
#                        from bpl-subset/bpl_subset/boost/thread/thread.hpp:22,
#                        from bpl-subset/bpl_subset/libs/thread/src/pthread/thread.cpp:11:
#       bpl-subset/bpl_subset/boost/bind/arg.hpp: In constructor ‘pycudaboost::arg<I>::arg(const T&)’:
#       bpl-subset/bpl_subset/boost/bind/arg.hpp:37:22: warning: typedef ‘T_must_be_placeholder’ locally defined but not used [-Wunused-local-typedefs]
#          37 |         typedef char T_must_be_placeholder[ I == is_placeholder<T>::value? 1: -1 ];
#             |                      ^~~~~~~~~~~~~~~~~~~~~
#       In file included from bpl-subset/bpl_subset/boost/thread/thread.hpp:24,
#                        from bpl-subset/bpl_subset/libs/thread/src/pthread/thread.cpp:11:
#       bpl-subset/bpl_subset/boost/thread/detail/thread_group.hpp: In member function ‘pycudaboost::thread* pycudaboost::thread_group::create_thread(F)’:
#       bpl-subset/bpl_subset/boost/thread/detail/thread_group.hpp:42:18: warning: ‘template<class> class std::auto_ptr’ is deprecated: use 'std::unique_ptr' instead [-Wdeprecated-declarations]
#          42 |             std::auto_ptr<thread> new_thread(new thread(threadfunc));
#             |                  ^~~~~~~~
#       In file included from /usr/include/c++/11/memory:76,
#                        from bpl-subset/bpl_subset/boost/move/move.hpp:38,
#                        from bpl-subset/bpl_subset/boost/thread/detail/move.hpp:20,
#                        from bpl-subset/bpl_subset/boost/thread/locks.hpp:11,
#                        from bpl-subset/bpl_subset/boost/thread/pthread/thread_data.hpp:11,
#                        from bpl-subset/bpl_subset/boost/thread/thread.hpp:17,
#                        from bpl-subset/bpl_subset/libs/thread/src/pthread/thread.cpp:11:
#       /usr/include/c++/11/bits/unique_ptr.h:57:28: note: declared here
#          57 |   template<typename> class auto_ptr;
#             |                            ^~~~~~~~
#       bpl-subset/bpl_subset/libs/thread/src/pthread/thread.cpp: In member function ‘bool pycudaboost::thread::do_try_join_until(const timespec&)’:
#       bpl-subset/bpl_subset/libs/thread/src/pthread/thread.cpp:379:5: warning: control reaches end of non-void function [-Wreturn-type]
#         379 |     }
#             |     ^
#       x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -fwrapv -Wall -O3 -DNDEBUG -fPIC -DBOOST_ALL_NO_LIB=1 -DBOOST_THREAD_BUILD_DLL=1 -DBOOST_MULTI_INDEX_DISABLE_SERIALIZATION=1 -DBOOST_PYTHON_SOURCE=1 -Dboost=pycudaboost -DBOOST_THREAD_DONT_USE_CHRONO=1 -DPYGPU_PACKAGE=pycuda -DPYGPU_PYCUDA=1 -DHAVE_CURAND=1 -Isrc/cpp -Ibpl-subset/bpl_subset -I/tmp/pip-build-env-xuwyzvs7/overlay/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c src/cpp/bitlog.cpp -o build/temp.linux-x86_64-cpython-310/src/cpp/bitlog.o
#       x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -fwrapv -Wall -O3 -DNDEBUG -fPIC -DBOOST_ALL_NO_LIB=1 -DBOOST_THREAD_BUILD_DLL=1 -DBOOST_MULTI_INDEX_DISABLE_SERIALIZATION=1 -DBOOST_PYTHON_SOURCE=1 -Dboost=pycudaboost -DBOOST_THREAD_DONT_USE_CHRONO=1 -DPYGPU_PACKAGE=pycuda -DPYGPU_PYCUDA=1 -DHAVE_CURAND=1 -Isrc/cpp -Ibpl-subset/bpl_subset -I/tmp/pip-build-env-xuwyzvs7/overlay/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c src/cpp/cuda.cpp -o build/temp.linux-x86_64-cpython-310/src/cpp/cuda.o
#       In file included from src/cpp/cuda.cpp:4:
#       src/cpp/cuda.hpp:14:10: fatal error: cuda.h: No such file or directory
#          14 | #include <cuda.h>
#             |          ^~~~~~~~
#       compilation terminated.
#       error: command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pycuda
# Failed to build pycuda
# ERROR: Could not build wheels for pycuda, which is required to install pyproject.toml-based projects
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/paragmraw/.local/lib/python3.10/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in /home/paragmraw/.local/lib/python3.10/site-packages (from opencv-python) (1.26.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/e2/7a/c7762c698fb1ac41a7e3afee51dc72aa3ec74ae8d2f57ce19a9cded3a4af/tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorflow) (2.0.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow)
#   Obtaining dependency information for flatbuffers>=23.5.26 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.4 MB/s eta 0:00:00
# Collecting h5py>=2.9.0 (from tensorflow)
#   Obtaining dependency information for h5py>=2.9.0 from https://files.pythonhosted.org/packages/0d/7a/e55589e4093cca1934db5e99644c1c2424a9b3aac104b7f6176605a5eeb7/h5py-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading h5py-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/ea/df/55525e489c43f9dbb6c8ea27d8a567b3dcd18a22f3c45483055f5ca6611d/libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata
#   Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes==0.2.0 (from tensorflow)
#   Obtaining dependency information for ml-dtypes==0.2.0 from https://files.pythonhosted.org/packages/d1/1d/d5cf76e5e40f69dbd273036e3172ae4a614577cb141673427b80cac948df/ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.23.5 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorflow) (1.26.0)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorflow) (4.24.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorflow) (4.8.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.2 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Obtaining dependency information for tensorflow-io-gcs-filesystem>=0.23.1 from https://files.pythonhosted.org/packages/88/99/8b507a009359fd55e411001acb64a1a8a4f81a26cb6e21c3b75c7fda4ae3/tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata
#   Downloading tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorflow) (2.14.1)
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.15,>=2.14.0 from https://files.pythonhosted.org/packages/d1/da/4f264c196325bb6e37a6285caec5b12a03def489b57cc1fdac02bb6272cd/tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.15,>=2.14.0 (from tensorflow)
#   Obtaining dependency information for keras<2.15,>=2.14.0 from https://files.pythonhosted.org/packages/fe/58/34d4d8f1aa11120c2d36d7ad27d0526164b1a8ae45990a2fede31d0e59bf/keras-2.14.0-py3-none-any.whl.metadata
#   Downloading keras-2.14.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/paragmraw/.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/paragmraw/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/paragmraw/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/paragmraw/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/paragmraw/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/paragmraw/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.0)
# Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 3.8 MB/s eta 0:00:0000:0100:03
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.7 MB/s eta 0:00:00a 0:00:01
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Downloading h5py-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 5.8 MB/s eta 0:00:0000:0100:01
# Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.7 MB/s eta 0:00:0000:0100:01
# Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 6.0 MB/s eta 0:00:0000:0100:01
# Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 6.7 MB/s eta 0:00:00a 0:00:01
# Downloading tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 7.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: libclang, flatbuffers, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, opt-einsum, ml-dtypes, keras, h5py, google-pasta, gast, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-23.5.26 gast-0.5.4 google-pasta-0.2.0 h5py-3.9.0 keras-2.14.0 libclang-16.0.6 ml-dtypes-0.2.0 opt-einsum-3.3.0 tensorflow-2.14.0 tensorflow-estimator-2.14.0 tensorflow-io-gcs-filesystem-0.34.0 termcolor-2.3.0 wrapt-1.14.1
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/paragmraw/.local/lib/python3.10/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in /home/paragmraw/.local/lib/python3.10/site-packages (from opencv-python) (1.26.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pygame
#   Obtaining dependency information for pygame from https://files.pythonhosted.org/packages/c8/c7/0d77e0e327bf09c12f445f92f5bad0b447375d7b836c5bac5255ead8436f/pygame-2.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pygame-2.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Downloading pygame-2.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 4.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pygame
# Successfully installed pygame-2.5.2

# %%
#SET HOME DIRECTORY
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/paragmraw/Coding/PAST_SEM/Data_Science/ADAS-Blind-Spot-Detection

# %%
#IMPORTING ULTRALYTICS YoloV8

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Setup complete ✅ (16 CPUs, 15.2 GB RAM, 75.1/219.5 GB disk)

# %%
#IMPORTING CUSTOM DATASET FROM ROBOFLOW
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from roboflow import Roboflow
rf = Roboflow(api_key="#API_KEY")                 #ENTER YOUR ROBOFLOW API KEY
project = rf.workspace("dayananda-sagar-university-q7oox").project("object-detection-for-safe-lane-changing")
dataset = project.version(1).download("yolov8")
# Out:
# /home/paragmraw/Coding/PAST_SEM/Data_Science/ADAS-Blind-Spot-Detection/datasets

# %%
#TRAINING
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data=datasets/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /home/paragmraw/Coding/PAST_SEM/Data_Science/ADAS-Blind-Spot-Detection
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.0.6) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=datasets/data.yaml, epochs=25, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /home/paragmraw/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 8.83MB/s]
# 2023-10-02 23:42:24.278830: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-02 23:42:24.300698: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-02 23:42:24.300732: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-02 23:42:24.300751: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-02 23:42:24.305428: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-02 23:42:24.814746: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.Detect                [2, [128, 256, 512]]
# Model summary: 225 layers, 11136374 parameters, 11136358 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /home/paragmraw/Coding/PAST_SEM/Data_Science/ADAS-Blind-Spot-Det
# train: New cache created: /home/paragmraw/Coding/PAST_SEM/Data_Science/ADAS-Blind-Spot-Detection/datasets/train/labels.cache
# val: Scanning /home/paragmraw/Coding/PAST_SEM/Data_Science/ADAS-Blind-Spot-Detec
# val: New cache created: /home/paragmraw/Coding/PAST_SEM/Data_Science/ADAS-Blind-Spot-Detection/datasets/valid/labels.cache
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      5.77G      1.579      4.624      1.395         24        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.636      0.646      0.603      0.388
#                   safe        140        197      0.847       0.65      0.779      0.416
#                 unsafe        140         14      0.425      0.643      0.428       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      5.52G      1.231      1.247      1.164         13        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.546      0.427      0.497      0.317
#                   safe        140        197      0.902      0.569      0.816      0.497
#                 unsafe        140         14      0.191      0.286      0.177      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      5.53G       1.19      1.155      1.086         28        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.804      0.888      0.899       0.65
#                   safe        140        197      0.814      0.846      0.883      0.481
#                 unsafe        140         14      0.794      0.929      0.915       0.82
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      5.49G      1.238       1.02      1.109         27        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.679      0.869      0.865      0.584
#                   safe        140        197      0.797      0.739      0.846      0.453
#                 unsafe        140         14       0.56          1      0.884      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      5.49G      1.252      1.111      1.112         16        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.698      0.919       0.82      0.569
#                   safe        140        197      0.873      0.838      0.892      0.463
#                 unsafe        140         14      0.523          1      0.748      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      5.49G      1.208     0.9258      1.085         15        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.811       0.74      0.889      0.661
#                   safe        140        197       0.99       0.48      0.903      0.526
#                 unsafe        140         14      0.633          1      0.875      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      5.49G      1.298     0.9348      1.129         27        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.678      0.882       0.91      0.622
#                   safe        140        197      0.853      0.764      0.883      0.509
#                 unsafe        140         14      0.504          1      0.937      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      5.49G       1.25     0.9113      1.116         19        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.783      0.919      0.882      0.617
#                   safe        140        197      0.782      0.838      0.866      0.492
#                 unsafe        140         14      0.783          1      0.897      0.742
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      5.49G      1.238     0.8362      1.101         23        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.745      0.872      0.876      0.604
#                   safe        140        197      0.865      0.745      0.878       0.51
#                 unsafe        140         14      0.626          1      0.875      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      5.49G      1.188      0.762      1.088         18        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.687      0.867      0.833      0.555
#                   safe        140        197      0.739      0.877      0.863      0.459
#                 unsafe        140         14      0.635      0.857      0.803       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      5.49G      1.264     0.8028      1.106         22        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.774       0.85       0.91      0.647
#                   safe        140        197      0.869      0.701      0.884      0.501
#                 unsafe        140         14       0.68          1      0.936      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      5.49G      1.198     0.7641      1.079         22        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.766      0.919       0.92      0.642
#                   safe        140        197      0.836      0.851      0.906      0.522
#                 unsafe        140         14      0.697      0.987      0.935      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      5.49G        1.2     0.7741      1.075         12        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.807      0.843      0.899      0.615
#                   safe        140        197      0.944      0.686      0.914      0.519
#                 unsafe        140         14       0.67          1      0.884      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      5.49G      1.184     0.7442      1.077         20        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.872      0.915      0.907      0.664
#                   safe        140        197      0.871      0.838      0.925       0.55
#                 unsafe        140         14      0.874      0.993      0.889      0.778
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      5.49G      1.192       0.72      1.069         14        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.861      0.874      0.932      0.702
#                   safe        140        197      0.905       0.82      0.923      0.555
#                 unsafe        140         14      0.818      0.929       0.94      0.848
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      5.49G      1.224     0.6965      1.088         14        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.842      0.891      0.935      0.667
#                   safe        140        197      0.902      0.782      0.916       0.55
#                 unsafe        140         14      0.782          1      0.954      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      5.49G      1.196     0.6926      1.071         15        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.869      0.773      0.913       0.69
#                   safe        140        197      0.919      0.689      0.908      0.548
#                 unsafe        140         14      0.819      0.857      0.918      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      5.49G      1.176     0.6396      1.069         17        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211       0.79      0.865      0.928      0.699
#                   safe        140        197      0.894      0.802      0.926      0.556
#                 unsafe        140         14      0.685      0.929       0.93      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      5.49G      1.146     0.6289      1.056         12        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.968      0.754      0.941       0.71
#                   safe        140        197      0.935       0.66      0.932      0.566
#                 unsafe        140         14          1      0.847       0.95      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      5.49G      1.172     0.6196      1.077         11        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.873      0.857      0.937      0.716
#                   safe        140        197      0.908      0.856      0.919      0.547
#                 unsafe        140         14      0.837      0.857      0.954      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      5.49G      1.119     0.6129       1.04         12        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.818      0.936      0.936      0.709
#                   safe        140        197      0.823      0.871      0.922      0.558
#                 unsafe        140         14      0.813          1       0.95       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25       5.5G      1.131     0.6166      1.028         11        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.819      0.929      0.936      0.703
#                   safe        140        197      0.849      0.858       0.92      0.551
#                 unsafe        140         14       0.79          1      0.952      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25       5.5G      1.132     0.5989      1.054         11        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.794      0.937      0.949      0.724
#                   safe        140        197      0.839      0.874      0.926      0.548
#                 unsafe        140         14      0.749          1      0.972        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25       5.5G      1.124     0.5795      1.043         13        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.825      0.924      0.947      0.713
#                   safe        140        197      0.884      0.848      0.929      0.569
#                 unsafe        140         14      0.766          1      0.964      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25       5.5G      1.119     0.5702      1.045         11        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.837       0.94      0.948      0.733
#                   safe        140        197      0.861       0.88      0.937      0.571
#                 unsafe        140         14      0.813          1      0.958      0.896
#
# 25 epochs completed in 0.086 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        140        211      0.837       0.94      0.948      0.733
#                   safe        140        197      0.861       0.88      0.937      0.571
#                 unsafe        140         14      0.812          1      0.958      0.896
# Speed: 1.3ms pre-process, 7.6ms inference, 0.0ms loss, 0.4ms post-process per image
# Results saved to runs/detect/train

# %%
#VALIDATION
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.0.6) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Traceback (most recent call last):
#   File "/home/paragmraw/.local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/yolo/cfg/__init__.py", line 230, in entrypoint
#     model = YOLO(model)
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 60, in __init__
#     {'.pt': self._load, '.yaml': self._new}[suffix](model)
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 90, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 384, in attempt_load_one_weight
#     ckpt = torch_safe_load(weight)  # load ckpt
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 332, in torch_safe_load
#     return torch.load(file, map_location='cpu')  # load
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/torch/serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/torch/serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/torch/serialization.py", line 252, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '{HOME}/runs/detect/train/weights/best.pt'
# Sentry is attempting to send 2 pending events
# Waiting up to 2 seconds
# Press Ctrl-C to quit

# %%
#PREDICTION
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.0.6) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Traceback (most recent call last):
#   File "/home/paragmraw/.local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/yolo/cfg/__init__.py", line 230, in entrypoint
#     model = YOLO(model)
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 60, in __init__
#     {'.pt': self._load, '.yaml': self._new}[suffix](model)
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 90, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 384, in attempt_load_one_weight
#     ckpt = torch_safe_load(weight)  # load ckpt
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 332, in torch_safe_load
#     return torch.load(file, map_location='cpu')  # load
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/torch/serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/torch/serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/home/paragmraw/.local/lib/python3.10/site-packages/torch/serialization.py", line 252, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '{HOME}/runs/detect/train/weights/best.pt'
# Sentry is attempting to send 2 pending events
# Waiting up to 2 seconds
# Press Ctrl-C to quit

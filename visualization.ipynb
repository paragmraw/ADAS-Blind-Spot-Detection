# %%
#SET HOME DIRECTORY
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/paragmraw/Coding/PAST_SEM/Data_Science/ADAS-Blind-Spot-Detection

# %%
from IPython.display import display, Image
import glob

# %%
#FILES OBTAINED AFTER TRAINING
# !ls runs/detect/train/
# Out:
# args.yaml					     train_batch2.jpg
# confusion_matrix.png				     train_batch435.jpg
# events.out.tfevents.1696270345.ROGUE0JAGUAR.10661.0  train_batch436.jpg
# F1_curve.png					     train_batch437.jpg
# P_curve.png					     val_batch0_labels.jpg
# PR_curve.png					     val_batch0_pred.jpg
# R_curve.png					     val_batch1_labels.jpg
# results.csv					     val_batch1_pred.jpg
# results.png					     val_batch2_labels.jpg
# train_batch0.jpg				     val_batch2_pred.jpg
# train_batch1.jpg				     weights

# %%
#CONFUSION MATRIX
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %%
#F1-CURVE
Image(filename=f'{HOME}/runs/detect/train/F1_curve.png', width=600)

# %%
#P-CURVE
Image(filename=f'{HOME}/runs/detect/train/P_curve.png', width=600)

# %%
#PR-CURVE
Image(filename=f'{HOME}/runs/detect/train/PR_curve.png', width=600)

# %%
#R-CURVE
Image(filename=f'{HOME}/runs/detect/train/R_curve.png', width=600)

# %%
#RESULTS
Image(filename=f'runs/detect/train/results.png', width=600)

# %%
#SAMPLE-IMAGES
Image(filename=f'runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
#SAMPLE-PREDICTIONS
for image_path in glob.glob(f'PAST_SEM/Data_Science/ADAS-Blind-Spot-Detection/runs/detect/predict/*.jpg')[:5]:
      display(Image(filename=image_path))
      print("\n")
